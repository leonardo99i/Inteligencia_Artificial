# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardo99i/Inteligencia_Artificial/blob/main/Proj_A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install matplotlib
# %pip install -U scikit-fuzzy

# %%
import matplotlib.pyplot as plt
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
if __name__=="__main__":

   #variáveis de entrada:
  
  ph = ctrl.Antecedent(np.arange(0, 18, 1), 'ph')
  cloramina = ctrl.Antecedent(np.arange(0, 200, 1), 'cloramina')  
  turbidez = ctrl.Antecedent(np.arange(0, 847, 1), 'turbidez')

  #variáveis de saída:
  potavel = ctrl.Consequent(np.arange(0, 1, 0.1),  'potavel')

  #fuzzificação:
  ph['acido'] = fuzz.trapmf((ph.universe), [0, 3, 5, 7])
  ph['neutro'] = fuzz.trimf((ph.universe), [6, 7, 7.2])
  ph['alcalino'] = fuzz.trapmf((ph.universe), [6.9, 10, 12, 14])

  cloramina['baixa'] = fuzz.trapmf(cloramina.universe, [0, 0, 45, 75])
  cloramina['media'] = fuzz.trapmf(cloramina.universe, [65, 75, 95, 105])
  cloramina['alta'] = fuzz.trapmf(cloramina.universe, [100, 110, 125, 130])

  turbidez['Transparente'] = fuzz.trapmf((turbidez.universe), [ 0, 0, 124, 282]) 
  turbidez['Turvo'] = fuzz.trapmf((turbidez.universe), [558, 640, 728, 847])
  turbidez['Muito Turvo'] = fuzz.trapmf((turbidez.universe), [558, 640, 728, 847]) 

  #Fuzzificação da Saída 
  potavel['Não Potavel'] = fuzz.trimf((potavel.universe), [0, 0, 0.6])
  potavel['Potavel'] = fuzz.trimf((potavel.universe), [0.2, 1, 1])  

  #definindo as regras

  regra1=ctrl.Rule(ph['acido']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra2=ctrl.Rule(ph['acido']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra3=ctrl.Rule(ph['acido']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra4=ctrl.Rule(ph['acido']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra5=ctrl.Rule(ph['acido']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra6=ctrl.Rule(ph['acido']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra7=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra8=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra9=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra10=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra11=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra12=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra13=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra14=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra15=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra16=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra17=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra18=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra19=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra20=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra21=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra22=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra23=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra24=ctrl.Rule(ph['neutro']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra25=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra26=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra27=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra28=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra29=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra30=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra31=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra32=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra33=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra34=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra35=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra36=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra37=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra38=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra39=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra40=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra41=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra42=ctrl.Rule(ph['neutro']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra43=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra44=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra45=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra46=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra47=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra48=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra49=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra50=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra51=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra52=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra53=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra54=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra55=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra56=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra57=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra58=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra59=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra60=ctrl.Rule(ph['neutro']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra61=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra62=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra63=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra64=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra65=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra66=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra67=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra68=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra69=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra70=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra71=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra72=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra73=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra74=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra75=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra76=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Transparente'],potavel['Potavel'])			
  regra77=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra78=ctrl.Rule(ph['alcalino']&cloramina['baixa']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra79=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra80=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra81=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra82=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra83=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra84=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra85=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra86=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra87=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra88=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra89=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra90=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra91=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra92=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra93=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra94=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Transparente'],potavel['Potavel'])			
  regra95=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra96=ctrl.Rule(ph['alcalino']&cloramina['media']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra97=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Transparente'],potavel['Não Potavel'])			
  regra98=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra99=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra100=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra101=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra102=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra103=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra104=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra105=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra106=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra107=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra108=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra109=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra110=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra111=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra112=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Transparente'],potavel['Potavel'])			
  regra113=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Turvo'],potavel['Não Potavel'])			
  regra114=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra115=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Não Potavel'])			
  regra116=ctrl.Rule(ph['alcalino']&cloramina['alta']&turbidez['Muito Turvo'],potavel['Potavel'])	


  #ativação de regras
controle_do_sistema = ctrl.ControlSystem([regra1,regra2,regra3,regra4,regra5,regra6,regra7,regra8,regra9,regra10,regra11,regra12,regra13,regra14,regra15,regra16,regra17,regra18,regra19,regra20,regra21,regra22,regra23,regra24,regra25,regra26,regra27,regra28,regra29,regra30,regra31,regra32,regra33,regra34,regra35,regra36,regra37,regra38,regra39,regra40,regra41,regra42,regra43,regra44,regra45,regra46,regra47,regra48,regra49,regra50,regra51,regra52,regra53,regra54,regra55,regra56,regra57,regra58,regra59,regra60,regra61,regra62,regra63,regra64,regra65,regra66,regra67,regra68,regra69,regra70,regra71,regra72,regra73,regra74,regra75,regra76,regra77,regra78,regra79,regra80,regra81,regra82,regra83,regra84,regra85,regra86,regra87,regra88,regra89,regra90,regra91,regra92,regra93,regra94,regra95,regra96,regra97,regra98,regra99,regra100,regra101,regra102,regra103,regra104,regra105,regra106,regra107,regra108,regra109,regra110,regra111,regra112,regra113,regra114,regra115,regra116])
simulador_potabilidade = ctrl.ControlSystemSimulation(controle_do_sistema)

  
  #mostrando os valores
simulador_potabilidade.input['ph'] = 7
simulador_potabilidade.input['cloramina'] = 3
simulador_potabilidade.input['turbidez'] = 2

simulador_potabilidade.compute()
print(simulador_potabilidade.output['potavel'])  

potavel.view(sim=simulador_potabilidade)
